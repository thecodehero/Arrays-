# %%
class ArrayList:
    def __init__(self):
        self.inArray = [0 for i in range(10)]
        self.count = 0
    
    
    def get(self, i):
        self._checkBounds(i, self.length())
        return self.inArray[i]

   
    def set(self, i, e):
        self._checkBounds(i, self.length())
        self.inArray[i] = e

    def length(self):
        return self.count

    def append(self, e):
        self.inArray[self.count] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
            
    
    def insert(self, i, e):
        self._checkBounds(i, self.length())
        for j in range(self.count,i,-1):
            self.inArray[j] = self.inArray[j-1]
        self.inArray[i] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
    

    def remove(self, i):
        self._checkBounds(i, self.length())
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray
        
    def _checkBounds(self, i, hi):  # checks whether i is in [0,hi]
        if i < 0 or i > hi:
            raise Exception("index "+str(i)+" out of bounds!") 
     
    
    def appendAll(self, A):
        for i in range(len(A)):
            self.append(A[i])
            
   
    def removeVal(self, e):
        for i in range(self.length()):
            if(e==self.inArray[i]):
                self.remove(i)
                return True
        return False
   
    def clone(self):           
        for i in range(self.length()):
            newArray.append(self.inArray[i])
        return newArray
    
  
    def sort(self): 
        for i in range(1,self.length()):
             self.insertionSort(self.inArray[i], i)
                
    def insertionSort(self, v, hi):
        for i in range(hi-1,-1,-1):
            if v >= self.inArray[i]:
                self.inArray[i+1] = v
                return
            self.inArray[i+1] = self.inArray[i]
        self.inArray[0] = v

# %%
#question 1
class ArrayList: 
    def __init__(self):
        self.inArray = [0 for i in range(10)]
        self.count = 0
    
    
    def get(self, i):
        self._checkBounds(i, self.length())
        return self.inArray[i]

    def set(self, i, e):
        self._checkBounds(i, self.length())
        self.inArray[i] = e

    def length(self):
        return self.count

    def append(self, e):
        self.inArray[self.count] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
            
    
    def insert(self, i, e):
        self._checkBounds(i, self.length())
        for j in range(self.count,i,-1):
            self.inArray[j] = self.inArray[j-1]
        self.inArray[i] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
    
  
    def remove(self, i):
        self._checkBounds(i, self.length())
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray
        
    def _checkBounds(self, i, hi):  # checks whether i is in [0,hi]
        if i < 0 or i > hi:
            raise Exception("index "+str(i)+" out of bounds!") 
     
    #question 1
    def appendAll(self, A):
        for i in range(len(A)):
            self.append(A[i])            
 
    def removeVal(self, e):
        for i in range(self.length()):
            if(e==self.inArray[i]):
                self.remove(i)
                return True
        return False
    

    def clone(self):           
        for i in range(self.length()):
            newArray.append(self.inArray[i])
        return newArray

    def sort(self): 
        for i in range(1,self.length()):
             self.insertionSort(self.inArray[i], i)
                
    def insertionSort(self, v, hi):
        for i in range(hi-1,-1,-1):
            if v >= self.inArray[i]:
                self.inArray[i+1] = v
                return
            self.inArray[i+1] = self.inArray[i]
        self.inArray[0] = v

ls = ArrayList()
ls.append(2)
ls.append(3)
ls.append(4)
ls.append(5)
ls.appendAll([42,24])
for j in range(ls.length()):    
    print(ls.get(j))
# Out:
# 2
# 3
# 4
# 5
# 42
# 24

# %%
#question2

class ArrayList:
    def __init__(self):
        self.inArray = [0 for i in range(10)]
        self.count = 0
    
    
    def get(self, i):
        self._checkBounds(i, self.length())
        return self.inArray[i]

    
    def set(self, i, e):
        self._checkBounds(i, self.length())
        self.inArray[i] = e

    def length(self):
        return self.count

    def append(self, e):
        self.inArray[self.count] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
   
    def insert(self, i, e):
        self._checkBounds(i, self.length())
        for j in range(self.count,i,-1):
            self.inArray[j] = self.inArray[j-1]
        self.inArray[i] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
    
 
    def remove(self, i):
        self._checkBounds(i, self.length())
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray
        
    def _checkBounds(self, i, hi):  # checks whether i is in [0,hi]
        if i < 0 or i > hi:
            raise Exception("index "+str(i)+" out of bounds!") 

    def appendAll(self, A):
        for i in range(len(A)):
            self.append(A[i])

    def removeVal(self, e):
        for i in range(self.length()):
            if(e==self.inArray[i]):
                self.remove(i)
                return True
        return False
    

    def clone(self):           
        for i in range(self.length()):
            newArray.append(self.inArray[i])
        return newArray
    
   
    def sort(self): 
        for i in range(1,self.length()):
             self.insertionSort(self.inArray[i], i)
                
    def insertionSort(self, v, hi):
        for i in range(hi-1,-1,-1):
            if v >= self.inArray[i]:
                self.inArray[i+1] = v
                return
            self.inArray[i+1] = self.inArray[i]
        self.inArray[0] = v

ls = ArrayList()
ls.append(2)
ls.append(3)
ls.append(4)
ls.append(5)
print(ls.removeVal(5))
print(ls.removeVal(10))
for j in range(ls.length()):    
    print(ls.get(j))
# Out:
# True
# False
# 2
# 3
# 4

# %%
#question 3
class ArrayList:
    def __init__(self):
        self.inArray = [0 for i in range(10)]
        self.count = 0
    
    
    def get(self, i):
        self._checkBounds(i, self.length())
        return self.inArray[i]

    def set(self, i, e):
        self._checkBounds(i, self.length())
        self.inArray[i] = e

    def length(self):
        return self.count

    def append(self, e):
        self.inArray[self.count] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
            
    
    def insert(self, i, e):
        self._checkBounds(i, self.length())
        for j in range(self.count,i,-1):
            self.inArray[j] = self.inArray[j-1]
        self.inArray[i] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
    
    def remove(self, i):
        self._checkBounds(i, self.length())
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray
        
    def _checkBounds(self, i, hi):  # checks whether i is in [0,hi]
        if i < 0 or i > hi:
            raise Exception("index "+str(i)+" out of bounds!") 
     
    
    def appendAll(self, A):
        for i in range(len(A)):
            self.append(A[i])
            
  
    def removeVal(self, e):
        for i in range(self.length()):
            if(e==self.inArray[i]):
                self.remove(i)
                return True
        return False
    
    #question 3
    def clone(self): 
        newArray = ArrayList()
        for i in range(self.length()):
            newArray.append(self.inArray[i])
        return newArray
    
    #question 4 
    def toArray(self):
        toArray = []
        for i in range(self.length()):
            toArray.append(self.inArray[i])
        return toArray    
   
    def sort(self): 
        for i in range(1,self.length()):
             self.insertionSort(self.inArray[i], i)
                
    def insertionSort(self, v, hi):
        for i in range(hi-1,-1,-1):
            if v >= self.inArray[i]:
                self.inArray[i+1] = v
                return
            self.inArray[i+1] = self.inArray[i]
        self.inArray[0] = v

ls = ArrayList()
ls.append(2)
ls.append(3)
ls.append(4)
ls.append(5)
for j in range(ls.length()):    
    print(ls.get(j)) 
print("Question 3")
B = ls.clone()
for j in range(ls.length()):    
    print(B.get(j))    
    
print("Question 4")
C = ls.toArray()    
print(C)
# Out:
# 2
# 3
# 4
# 5
# Question 3
# 2
# 3
# 4
# 5
# Question 4
# [2, 3, 4, 5]

# %%
#question 5
class ArrayList:
    def __init__(self):
        self.inArray = [0 for i in range(10)]
        self.count = 0
    
    #question 5
    def get(self, i):
        self._checkBounds(i, self.length())
        return self.inArray[i]

    #question 5
    def set(self, i, e):
        self._checkBounds(i, self.length())
        self.inArray[i] = e

    def length(self):
        return self.count

    def append(self, e):
        self.inArray[self.count] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
            
    #question 5
    def insert(self, i, e):
        self._checkBounds(i, self.length())
        for j in range(self.count,i,-1):
            self.inArray[j] = self.inArray[j-1]
        self.inArray[i] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
    
    #question 5
    def remove(self, i):
        self._checkBounds(i, self.length())
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray
        
    def _checkBounds(self, i, hi):  # checks whether i is in [0,hi]
        if i < 0 or i > hi:
            raise Exception("index "+str(i)+" out of bounds!") 
     
 
    def appendAll(self, A):
        for i in range(len(A)):
            self.append(A[i])
            
 
    def removeVal(self, e):
        for i in range(self.length()):
            if(e==self.inArray[i]):
                self.remove(i)
                return True
        return False
    
   
    def clone(self):           
        for i in range(self.length()):
            newArray.append(self.inArray[i])
        return newArray

    def toArray(self):
        toArray = []
        for i in range(self.length()):
            toArray.append(self.inArray[i])
        return toArray
        
    
    #question 6
    def sort(self): 
        for i in range(1,self.length()):
             self.insertionSort(self.inArray[i], i)
                
    def insertionSort(self, v, hi):
        for i in range(hi-1,-1,-1):
            if v >= self.inArray[i]:
                self.inArray[i+1] = v
                return
            self.inArray[i+1] = self.inArray[i]
        self.inArray[0] = v

ls = ArrayList()
ls.append(2)
ls.append(3)
ls.append(4)
ls.append(5)
for j in range(ls.length()):    
    print(ls.get(j))  
print("Question 5")
ls.set(3,7)
ls.insert(2,3)
ls.remove(5)
# Out:
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-14-735fcc5f7838> in <module>
#     101 ls.set(3,7)
#     102 ls.insert(2,3)
# --> 103 ls.remove(-5)
#
# <ipython-input-14-735fcc5f7838> in remove(self, i)
#      36     #question 5
#      37     def remove(self, i):
# ---> 38         self._checkBounds(i, self.length())
#      39         self.count -= 1
#      40         val = self.inArray[i]
#
# <ipython-input-14-735fcc5f7838> in _checkBounds(self, i, hi)
#      51     def _checkBounds(self, i, hi):  # checks whether i is in [0,hi]
#      52         if i < 0 or i > hi:
# ---> 53             raise Exception("index "+str(i)+" out of bounds!")
#      54
#      55
#
# Exception: index -5 out of bounds!

# %%
#question 6
class ArrayList:
    def __init__(self):
        self.inArray = [0 for i in range(10)]
        self.count = 0
    
   
    def get(self, i):
        self._checkBounds(i, self.length())
        return self.inArray[i]


    def set(self, i, e):
        self._checkBounds(i, self.length())
        self.inArray[i] = e

    def length(self):
        return self.count

    def append(self, e):
        self.inArray[self.count] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
            
    
    def insert(self, i, e):
        self._checkBounds(i, self.length())
        for j in range(self.count,i,-1):
            self.inArray[j] = self.inArray[j-1]
        self.inArray[i] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
    
 
    def remove(self, i):
        self._checkBounds(i, self.length())
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray
        
    def _checkBounds(self, i, hi):  # checks whether i is in [0,hi]
        if i < 0 or i > hi:
            raise Exception("index "+str(i)+" out of bounds!") 
     

    def appendAll(self, A):
        for i in range(len(A)):
            self.append(A[i])

    def removeVal(self, e):
        for i in range(self.length()):
            if(e==self.inArray[i]):
                self.remove(i)
                return True
        return False
    
 
    def clone(self):           
        for i in range(self.length()):
            newArray.append(self.inArray[i])
        return newArray
    
    
    
    #question 6
    def sort(self): 
        for i in range(1,self.length()):
             self.insertionSort(self.inArray[i], i)
                
    def insertionSort(self, v, hi):
        for i in range(hi-1,-1,-1):
            if v >= self.inArray[i]:
                self.inArray[i+1] = v
                return
            self.inArray[i+1] = self.inArray[i]
        self.inArray[0] = v

ls = ArrayList()
ls.append(5)
ls.append(2)
ls.append(3)
ls.append(4)
for j in range(ls.length()):    
    print(ls.get(j))  

print("sorted")
ls.sort()

for j in range(ls.length()):    
    print(ls.get(j))
# Out:
# 5
# 2
# 3
# 4
# sorted
# 2
# 3
# 4
# 5

# %%
#question 7
class PQueue:
    def __init__(self):
        self.inArray = [0 for i in range(15)]
        self.count = 0            
        
    def size(self):
        return self.count

    def enq(self, e):    #inserts in order of highest priority
        i=0
        while i < self.size() and self.get(i).priority < e.priority:
            i += 1
        self.insert(i,e)
            
    def deq(self): #remove element with highest priority.                     
        return self.remove(self.size()-1)
    
    def insert(self, i, e):
        self._checkBounds(i, self.size())
        for j in range(self.count,i,-1):
            self.inArray[j] = self.inArray[j-1]
        self.inArray[i] = e
        self.count += 1
        if len(self.inArray) == self.count:
            self._resizeUp()
            
    def remove(self, i):
        self._checkBounds(i, self.size())
        self.count -= 1
        val = self.inArray[i]
        for j in range(i,self.count):
            self.inArray[j] = self.inArray[j+1]
        return val
    
    def _checkBounds(self, i, hi):  # checks whether i is in [0,hi]
        if i < 0 or i > hi:
            raise Exception("index "+str(i)+" out of bounds!")
            
    def get(self, i):
        self._checkBounds(i, self.size())
        return self.inArray[i]       

    def _resizeUp(self):
        newArray = [0 for i in range(2*len(self.inArray))]
        for j in range(len(self.inArray)):
            newArray[j] = self.inArray[j]
        self.inArray = newArray
    
    def __str__(self):
        array = "["
        for i in range(self.size()-1,-1,-1):
            array = array + str(self.get(i)) 
        array = array + "]"
        return array   
    
class PQElement:
    def __init__(self, v, p):
        self.val = v
        self.priority = p
        
    def __str__(self):
        return "("+str(self.val)+","+str(self.priority)+")"
            
        
ls = PQueue()
for i in range(15):
    ls.enq(PQElement(i,10-i))
print(ls)
print(ls.deq(),ls)
# Out:
# [(0,10)(1,9)(2,8)(3,7)(4,6)(5,5)(6,4)(7,3)(8,2)(9,1)(10,0)(11,-1)(12,-2)(13,-3)(14,-4)]
# (0,10) [(1,9)(2,8)(3,7)(4,6)(5,5)(6,4)(7,3)(8,2)(9,1)(10,0)(11,-1)(12,-2)(13,-3)(14,-4)]
